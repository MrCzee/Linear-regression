# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 1: Understanding & Reading Dataset

# %%
data = pd.read_csv('Salary_Data.csv')

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.shape
# Out:
# (30, 2)

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plot the bar graph
plt.bar(data['YearsExperience'], data['Salary'], color='skyblue')

# Add labels and a title
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Years of Experience vs Salary")

# Rotate x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Adjust layout to prevent label clipping
plt.tight_layout()

# Display the plot
plt.show()

# %%
plt.scatter(data['YearsExperience'], data['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Years of Experience vs Salary')
plt.show()

# %% [markdown]
# Step : 03 : Performing simple Linear Regression Model

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = data[['YearsExperience']]
y = data[['Salary']]

#x_train, y_train, x_test, y_test = train_test_split(data[['YearsExperience']], data[['Salary']], test_size=0.2, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#     YearsExperience
# 28             10.3
# 24              8.7
# 12              4.0
# 0               1.1
# 4               2.2
# 16              5.1
# 5               2.9
# 13              4.1
# 11              4.0
# 22              7.9
# 1               1.3
# 2               1.5
# 25              9.0
# 3               2.0
# 21              7.1
# 26              9.5
# 18              5.9
# 29             10.5
# 20              6.8
# 7               3.2
# 10              3.9
# 14              4.5
# 19              6.0
# 6               3.0

# %%
y_train
# Out:
#       Salary
# 28  122391.0
# 24  109431.0
# 12   56957.0
# 0    39343.0
# 4    39891.0
# 16   66029.0
# 5    56642.0
# 13   57081.0
# 11   55794.0
# 22  101302.0
# 1    46205.0
# 2    37731.0
# 25  105582.0
# 3    43525.0
# 21   98273.0
# 26  116969.0
# 18   81363.0
# 29  121872.0
# 20   91738.0
# 7    54445.0
# 10   63218.0
# 14   61111.0
# 19   93940.0
# 6    60150.0

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (24, 1)
# (24, 1)
# (6, 1)
# (6, 1)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-b5a7926a6890> in <cell line: 0>()
# ----> 1 x_train.reshape
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %% [markdown]
# Step: 04 - Model analysis:
#
# ```
# # This is formatted as code
# ```

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_train,y_train)

#model = LinearRegression().fit(x_train, y_train)

# %% [markdown]
# Plotting: x_train, y_train values

# %%
plt.scatter(x_train, y_train, color='blue')
plt.plot(x_train, model.predict(x_train), color='red')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Checking Model's Performance

# %%
model.score(x_train, y_train)
# Out:
# 0.9645401573418146

# %% [markdown]
# Perdicting values / Testing Model on random values

# %%
print("Expected Salay", model.predict([[2.5]]))
# Out:
# Expected Salay [[48881.12131935]]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
